# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
saintsDF = pd.read_csv("saints.csv")

# %%
 sns.countplot(x = "PlayType", data = saintsDF, palette= "Blues")

# %%
sns.countplot(x = "PlayType", 
data = saintsDF[(saintsDF["Down"] == 3) & (saintsDF["Yards"] < 2)], 
palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Down"] == 1], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Down"] == 2], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Down"] == 3], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Quarter"] == 1], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Quarter"] == 2], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Quarter"] == 3], palette= "Blues")

# %%
sns.countplot(x = "PlayType", data = saintsDF[saintsDF["Quarter"] == 4], palette= "Blues")

# %%
sns.stripplot(x = "ToGo", y="Yards", data = saintsDF)

# %%
sns.regplot(x="YardLine", y="Yards", data = saintsDF)
